# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from warnings import filterwarnings

# %matplotlib inline

# %%
df = pd.read_csv("E:\\FSM\\TERMS\\TERM 2\\Python\\FInal project\\Cleaned_2018_Flights.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       ItinID          MktID  MktCoupons  Quarter Origin  \
# 0           0  20181767585  2018176758501           1        1    PHL
# 1           1  20181767586  2018176758601           1        1    PHL
# 2           2  20181767587  2018176758701           1        1    PHL
# 3           3  20181767636  2018176763601           1        1    PHL
# 4           4  20181767637  2018176763701           1        1    PHL
#
#    OriginWac Dest  DestWac   Miles  ContiguousUSA  NumTicketsOrdered  \
# 0         23  LAX       91  2402.0              2                1.0
# 1         23  LAX       91  2402.0              2                1.0
# 2         23  LAX       91  2402.0              2                1.0
# 3         23  LAX       91  2402.0              2                1.0
# 4         23  LAX       91  2402.0              2                1.0
#
#   AirlineCompany  PricePerTicket
# 0             AA          672.87
# 1             AA          367.68
# ...

# %%
df.shape
# Out:
# (9534417, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9534417 entries, 0 to 9534416
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   ItinID             int64
#  2   MktID              int64
#  3   MktCoupons         int64
#  4   Quarter            int64
#  5   Origin             object
#  6   OriginWac          int64
#  7   Dest               object
#  8   DestWac            int64
#  9   Miles              float64
#  10  ContiguousUSA      int64
#  11  NumTicketsOrdered  float64
#  12  AirlineCompany     object
#  13  PricePerTicket     float64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1018.4+ MB

# %%
df.tail()
# Out:
#          Unnamed: 0        ItinID           MktID  MktCoupons  Quarter Origin  \
# 9534412     9534412  201844999082  20184499908202           1        4    STL
# 9534413     9534413  201844999092  20184499909203           1        4    BNA
# 9534414     9534414  201844999112  20184499911203           1        4    BOS
# 9534415     9534415  201844999113  20184499911303           1        4    BOS
# 9534416     9534416  201844999114  20184499911403           1        4    BOS
#
#          OriginWac Dest  DestWac   Miles  ContiguousUSA  NumTicketsOrdered  \
# 9534412         64  AUS       74   721.0              2                1.0
# 9534413         54  MCI       64   491.0              2                1.0
# 9534414         13  LIT       71  1260.0              2                1.0
# 9534415         13  LIT       71  1260.0              2                1.0
# 9534416         13  LIT       71  1260.0              2                1.0
#
#         AirlineCompany  PricePerTicket
# ...

# %%
df.MktCoupons.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df.ContiguousUSA.unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df.Miles.unique()
# Out:
# array([2402., 1744., 2446., ...,  897., 2420.,  565.])

# %%
df.NumTicketsOrdered.unique()
# Out:
# array([ 1.,  2.,  3.,  6.,  9.,  5.,  4., 10.,  8., 20., 14., 11., 19.,
#        12.,  7., 16., 17., 15., 13., 18.])

# %%
df.Quarter.unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
df.AirlineCompany.unique()
# Out:
# array(['AA', 'AS', 'DL', 'UA', 'B6', 'SY', 'WN', 'F9', 'G4', 'HA', 'NK',
#        'VX'], dtype=object)

# %%
fig=plt.figure( )
sns.displot(df['PricePerTicket'], color ='red', bins = 30)
plt.title('Histogram of Price Per Ticket', fontsize =15)
# Out:
# Text(0.5, 1.0, 'Histogram of Price Per Ticket')

# %%
#Analysis of MIlES

sns.displot(df['Miles'],bins =50)
plt.title('Histogram of Miles')
# Out:
# Text(0.5, 1.0, 'Histogram of Miles')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# ItinID               0
# MktID                0
# MktCoupons           0
# Quarter              0
# Origin               0
# OriginWac            0
# Dest                 0
# DestWac              0
# Miles                0
# ContiguousUSA        0
# NumTicketsOrdered    0
# AirlineCompany       0
# PricePerTicket       0
# dtype: int64

# %%
#CHECKING MEAN, STD, MAXIMUM & MINIMUM VALUES OF TICKET PRICES

df.PricePerTicket.describe()
# Out:
# count    9.534417e+06
# mean     2.324497e+02
# std      1.433412e+02
# min      5.000000e+01
# 25%      1.339100e+02
# 50%      1.971900e+02
# 75%      2.900000e+02
# max      1.000000e+03
# Name: PricePerTicket, dtype: float64

# %%
sns.scatterplot(x='PricePerTicket',y='NumTicketsOrdered',data=df)
# Out:
# <AxesSubplot:xlabel='PricePerTicket', ylabel='NumTicketsOrdered'>

# %%
sns.jointplot(x='PricePerTicket',y='Miles',data=df)

# %%
sns.displot(df['Miles'])

# %%
sns.countplot(x='Quarter',data=df)
# Out:
# <AxesSubplot:xlabel='Quarter', ylabel='count'>

# %%
sns.countplot(x='MktCoupons',data=df)
# Out:
# <AxesSubplot:xlabel='MktCoupons', ylabel='count'>

# %%
#Analysis of airline companies

#WN airline has the most booked flights in2018

sns.countplot(x='AirlineCompany',data=df)
# Out:
# <AxesSubplot:xlabel='AirlineCompany', ylabel='count'>

# %%
sns.heatmap(df.corr(), annot = True).set_title('Heat Map')
# Out:
# Text(0.5, 1.0, 'Heat Map')

# %%
sns.catplot(x='AirlineCompany', y='PricePerTicket',data=df)

# %%
sns.boxplot(x='AirlineCompany', y='PricePerTicket',data=df)
# Out:
# <AxesSubplot:xlabel='AirlineCompany', ylabel='PricePerTicket'>

# %%
sns.catplot(x='Quarter', y='PricePerTicket',data=df)

# %%
sns.catplot(x='MktCoupons', y='PricePerTicket',data=df)

# %%
sns.jointplot(df['Miles'],df['PricePerTicket'], kind= 'hex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(x='AirlineCompany', y='Quarter',data=df)
# Out:
# <AxesSubplot:xlabel='AirlineCompany', ylabel='Quarter'>

# %%
plt.figure(figsize=(10,8))
sns.relplot(x='Quarter', y='PricePerTicket',kind='scatter',data=df)
